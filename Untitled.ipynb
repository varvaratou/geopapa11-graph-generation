# %%
# %matplotlib inline
from train import *

# %%
args = Args()
graphs = create_graphs.create(args)

# %%
graphs

# %%
draw_graph_list(graphs, 3, 4)

# %%
for i in range(0, 160, 16):
    draw_graph_list(graphs[i:i+16], 4, 4, fname='figures/community4_' + str(i))

# %%
plt.show()

# %%
# !conda list
# Out:
# # packages in environment at /Users/geopap/opt/anaconda3/envs/graph-generation:
# #
# # Name                    Version                   Build  Channel
# _pytorch_select           0.1                       cpu_0
# absl-py                   1.0.0                    pypi_0    pypi
# appnope                   0.1.0                    py37_0    anaconda
# astunparse                1.6.3                    pypi_0    pypi
# attrs                     21.2.0             pyhd3eb1b0_0
# backcall                  0.2.0                      py_0    anaconda
# bleach                    4.1.0              pyhd3eb1b0_0
# ca-certificates           2021.10.26           hecd8cb5_2
# cached-property           1.5.2                    pypi_0    pypi
# cachetools                4.2.4                    pypi_0    pypi
# certifi                   2021.10.8        py37hecd8cb5_2
# cffi                      1.14.6           py37h2125817_0
# charset-normalizer        2.0.10                   pypi_0    pypi
# ...
